# %% [markdown]
# # Bugs to report
#
# 1.     "markdownCellConfig": {
#         "lineNumbers": false,
#         "matchBrackets": false
#     },
#     "rawCellConfig": {
#         "lineNumbers": true,
#         "matchBrackets": true
#     },
#
# Doesn't seem to work
#
# 2. ⇧ + ⌘ + K -- both shows the TOC but also deletes text.
#
# 3. Why doesn't markdown preview render correctly? (See the stupid apostrophes, lack of bold and italics, etc.)
#
# ![Screenshot 2024-04-09 at 3.50.15 PM.png](attachment:4a388793-c8cd-46f6-a077-7914424d1a80.png)
#
# 4. (Z) doesn't undo splits and retain cell types. Combine 3 markdown cells, undo, and several return to markdown.
#
# 5. Some browser specific fun:  ⇧ ⌘ B will not hide/show the bookmark toolbar.
#
# 6. Autoclosing brackets? Why two?
# - Preferences:
#     - Settings -> Code Console
#         - Select: Auto Closing Brackets
#     - Settings -> CodeMirror
#         - Select: Auto Closing Brackets
#
# 7. Turning on line numbers via
# - Preferences:
#     - Settings -> Code Console
#         - Select: Line Numbering
#     - Settings -> CodeMirror
#         - Select: Line Numbering
#
# open ticket: https://github.com/jupyterlab/jupyterlab/issues/15267
#
# 8. Settings search doesn't find Line Numbering (for example)

# %% [markdown]
# ## Website problems:
#
#  - https://jupyterlab.readthedocs.io/en/latest/getting_started/changelog.html
#     > "because their model is read-only." -- mode not model
#
#  - https://jupyter-notebook.readthedocs.io/en/stable/notebook.html#introduction
#     > "Jupyter Notebook Viewer <nbviewer>" -- meant to be a link to https://nbviewer.org/
#
#     > https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html#Local-files
#         ![Screenshot 2024-04-11 at 12.01.13 PM.png](attachment:ce313c6d-edf3-4008-9d21-eb19e1122e6c.png)
#
#  - https://jupyterlab-realtime-collaboration.readthedocs.io/en/latest/api/modules/collaboration.html
#     > Link is to: https://jupyter-realtime-collaboration.readthedocs.io/en/latest  which is an error
#     ![Screenshot 2024-04-11 at 12.34.19 PM.png](attachment:b71eef25-e9bf-427a-91e5-facd5d99a94c.png)
